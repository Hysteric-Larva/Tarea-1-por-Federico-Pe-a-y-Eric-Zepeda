# %% [markdown]
# # Workshop

# %%
import random
import pandas as pd
import numpy as np
df = pd.read_csv("timesData.csv")
df.shape
# Out:
# (2603, 14)

# %%
df.columns.tolist()

# %%
df.head(1)

# %%
#df.corr

# %%
a=np.random.choice(20, 10, replace=False) # con esto puedo tomar 10 datos al azar entre 0 a 20 sin repetir.
print (a)

# %%
def convertToInt(x):
    try:
        x = int(x)
    except:
        x = '-'
    return x
df.dropna(axis=0,inplace=True,how='any') #borra nan
df['total_score'] = df['total_score'].apply(lambda x: x.replace('-','unknown')) #rellena 
df = df[~(df == '-').any(axis=1)] #elimina filas con valores nulos
df.shape
# Out:
# (0, 16)

# %%
def convertToInt(x):
    try:
        x = int(x)
    except:
        x = '-'
    return x;



def has_nan(df):
    if df.isnull().any().any() == True:
            return True;
    else:
        return False;

def nan_clean(df):
    count = 0
    cs = 0
    if has_nan(df)==False:
        return df
    else:
        df1 = df.replace(np.nan, '-', regex=True)
        for index, row in df1.iterrows():
            for i in row:
                if i =='-' and index== 0:
                    
                    print("hola")
                    count+=1
                elif i =='-' and index!= 0:
                    print("aaaaaaaaaa")
                    count+=1
                else:
                    print("b")
                    
        print(str(count))
        return df1
def fraction(x,y):
    #suposicion x<y
    for i in range(x+1):
        if i!=0: 
            if x%i==0 and y%i==0 and i!=0:
                list[0]=x/i
                list[1]=y/i
    return list;
def d(df,i,k):
    dif=0
    dk = df['total_score']
    dif = float(dk[k-1])- float(dk[k+1])
    return dif;
def pos_y(df1,k):
    dif=0
    a=int(k)-1
    b=int(k)+1
    dif = float(df1['total_score'][a]) - float(df1['total_score'][b])
    dx=dif
    y = (dx**2)/(dx+0.1)
    return y;
def max_error(df,k):
    sum=0
    error1 = 0
    error2 = 0
    datos = 10 - v_lost
    for i in df:
        if df[i][k]!='-' and df[i][k]!=df['world_rank'][k]  and df[i][k]!=df['total_score'][k] :

            contador1= int(k)+1
            while df[i][contador1]=='-':
                contador1+=1

            error1= abs(float(df[i][k]) - float(df[i][contador1]))
            contador2 = int(k)-1

            
            error2 = abs(float(df[i][k]) - float(df[i][contador2]))
            if error1 > error2:
                sum=sum + error1
            elif error1 <= error2:
                sum=sum + error2
        
    return sum;
def min_error(df,k):
    sum=0

    error1 = 0
    error2 = 0
    datos = 10 - v_lost
    for i in df:
        if df[i][k]!='-' and df[i][k]!=df['world_rank'][k]  and df[i][k]!=df['total_score'][k] :
            contador1= int(k)+1
            while df[i][contador1]=='-':
                contador1+=1

            error1= abs(float(df[i][k]) - float(df[i][contador1]))
            contador2 = int(k)-1
            while df[i][contador2]=='-':
                contador2= contador2-1
            
            error2 = abs(float(df[i][k]) - float(df[i][contador2]))
            if error1 > error2:
                sum=sum + error2
            elif error1 <= error2:
                sum=sum + error1

    return sum;

# %%
#nuevo_df  = pd.get_dummies(df, columns=["country"]) #column to categorical
#nuevo_df['female'] = nuevo_df['female_male_ratio'].str.split(':', expand=True)[0].apply(convertToInt)
#nuevo_df['male'] = nuevo_df['female_male_ratio'].str.split(':', expand=True)[1].apply(convertToInt)
#nuevo_df['female_male_ratio'] =  np.where(nuevo_df['male'] == 0, 0, nuevo_df['female']/(nuevo_df['male']+1) #si no hay (rellena 0) 
#nuevo_df['num_students'] = nuevo_df['num_students'].apply(lambda x: int(str(x).replace(',','')))
#nuevo_df['international_students'] = nuevo_df['international_students'].apply(lambda x: int(str(x).replace('%','')))
nan_clean(df)
# Out:
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# hola
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# aaaaaaaaaa
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# aaaaaaaaaa
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# aaaaaaaaaa
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# aaaaaaaaaa
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# aaaaaaaaaa
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# aaaaaaaaaa
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# aaaaaaaaaa
# b
# b
# ...

# %%
c=1 # contador
if has_nan(df)==False:
        print("fake")
else:
    df1 = df.replace(np.nan, '-', regex=True)
    df_test = df1[df1["total_score"]=='-']
    df1 =  df1[df1["total_score"]!='-']
    df1['female'] = df1['female_male_ratio'].str.split(':', expand=True)[0].apply(convertToInt)
    df1['male'] = df1['female_male_ratio'].str.split(':', expand=True)[1].apply(convertToInt)
    df1['num_students'] = df1['num_students'].apply(lambda x: str(x).replace(',','')).apply(convertToInt)
    df1['international_students'] = df1['international_students'].apply(lambda x: str(x).replace('%','')).apply(convertToInt)
    df1=df1.drop(['female_male_ratio'], axis=1)
    df1=df1.drop(['year'], axis=1)
    df1=df1.drop(['country'], axis=1)
    df1=df1.drop(['university_name'], axis=1)

    for k in range(len(df1)):
        v_lost = 0
        v_lost_list = []
        for i in df1:
        
            if  df1[i][k]!='-' and df1[i][k]!=df1['world_rank'][k] and  df1[i][k]!=df1['total_score'][k]:   
                v_lost_list.append(i)
            elif v_lost>3:
                df1.drop(k, axis=0)
                pass
            else:
                pass
        if v_lost_list!=[]:
            for j in v_lost_list:
                c=1 
                if k==0:
                    
                    df1[j][k] = df1[j][c]
                    pass
                elif k!=0:
                    y = pos_y(df1,k)
                    m =  min_error(df1,k)
                    M = max_error(df1,k)
                    dist = d(df1,j,k)
                    delta = (m*dist)/M
                    inf = y-delta
                    sup = y + delta
                    df1[j][k] = inf + 2*delta*np.random.random_sample()
# Out:
# C:\Users\kzep\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-d114c6041eca> in <module>()
#      36                 elif k!=0:
#      37                     y = pos_y(df1,k)
# ---> 38                     m =  min_error(df1,k)
#      39                     M = max_error(df1,k)
#      40                     dist = d(df1,j,k)
#
# <ipython-input-63-6b8c137ca366> in min_error(df, k)
#      93             error1= abs(float(df[i][k]) - float(df[i][contador1]))
#      94             contador2 = int(k)-1
# ---> 95             while df[i][contador2]=='-':
# ...

# %%
# Out:
# 2603

# %%
x= 3
y=9
list = fraction(x,y)

# %%
print(list)
# Out:
# [1.0, 3.0]

# %%
for i in df:
    df[i][0] = 2
    print(df[i][0])
# Out:
# C:\Users\kzep\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 2
# 2
# 2
# 2.0
# 2
# 2.0
# 2.0
# 2
# 2
# 2
# 2.0
# 2
# 2
# 2

# %%
df = df.replace(np.nan, '-', regex=True)
df_test = df[df["total_score"]=='-']
df =  df[df["total_score"]!='-']
df['female'] = df['female_male_ratio'].str.split(':', expand=True)[0].apply(convertToInt)
df['male'] = df['female_male_ratio'].str.split(':', expand=True)[1].apply(convertToInt)
df['num_students'] = df['num_students'].apply(lambda x: str(x).replace(',','')).apply(convertToInt)
df['international_students'] = df['international_students'].apply(lambda x: str(x).replace('%','')).apply(convertToInt)
df.drop(['female_male_ratio','year'], axis=1)
# Out:
#      world_rank                                    university_name  \
# 0             1                                 Harvard University
# 1             2                 California Institute of Technology
# 2             3              Massachusetts Institute of Technology
# 3             4                                Stanford University
# 4             5                               Princeton University
# 5             6                            University of Cambridge
# 6             6                               University of Oxford
# 7             8                 University of California, Berkeley
# 8             9                            Imperial College London
# 9            10                                    Yale University
# 10           11              University of California, Los Angeles
# 11           12                              University of Chicago
# 12           13                           Johns Hopkins University
# ...

# %%
df.head(100)
# Out:
#    world_rank                                    university_name  \
# 0           1                                 Harvard University
# 1           2                 California Institute of Technology
# 2           3              Massachusetts Institute of Technology
# 3           4                                Stanford University
# 4           5                               Princeton University
# 5           6                            University of Cambridge
# 6           6                               University of Oxford
# 7           8                 University of California, Berkeley
# 8           9                            Imperial College London
# 9          10                                    Yale University
# 10         11              University of California, Los Angeles
# 11         12                              University of Chicago
# 12         13                           Johns Hopkins University
# ...

# %%
df1 = df

# %%
df1.drop(['female_male_ratio','year'], axis=1)
# Out:
#      world_rank                                    university_name  \
# 0             1                                 Harvard University
# 1             2                 California Institute of Technology
# 2             3              Massachusetts Institute of Technology
# 3             4                                Stanford University
# 4             5                               Princeton University
# 5             6                            University of Cambridge
# 6             6                               University of Oxford
# 7             8                 University of California, Berkeley
# 8             9                            Imperial College London
# 9            10                                    Yale University
# 10           11              University of California, Los Angeles
# 11           12                              University of Chicago
# 12           13                           Johns Hopkins University
# ...

# %%
df1.head(100)
# Out:
#    world_rank                                    university_name  \
# 0           1                                 Harvard University
# 1           2                 California Institute of Technology
# 2           3              Massachusetts Institute of Technology
# 3           4                                Stanford University
# 4           5                               Princeton University
# 5           6                            University of Cambridge
# 6           6                               University of Oxford
# 7           8                 University of California, Berkeley
# 8           9                            Imperial College London
# 9          10                                    Yale University
# 10         11              University of California, Los Angeles
# 11         12                              University of Chicago
# 12         13                           Johns Hopkins University
# ...

# %%
dk = df1['total_score']

# %%
dk.head(100)
# Out:
# 0        96.0
# 1        0.32
# 2    -94.0801
# 3     -188.38
# 4     -279.68
# 5     -370.98
# 6     -462.18
# 7     -552.88
# 8     -642.48
# 9     -730.28
# 10    -817.28
# 11    -903.78
# 12    -987.78
# 13   -1071.28
# 14   -1154.78
# 15   -1236.88
# 16   -1317.98
# 17   -1397.58
# 18   -1476.98
# 19   -1556.28
# 20   -1634.78
# 21   -1712.88
# 22   -1789.48
# 23   -1865.48
# 24   -1941.18
# 25   -2016.58
# 26   -2091.78
# 27   -2166.88
# 28   -2240.78
# 29   -2314.68
#        ...
# 70   -5022.78
# 71   -5083.58
# 72   -5144.38
# 73   -5204.88
# 74   -5265.28
# 75   -5325.08
# 76   -5384.78
# 77   -5444.38
# 78   -5503.98
# 79   -5563.18
# 80   -5622.38
# 81   -5681.48
# 82   -5740.58
# 83   -5799.58
# 84   -5857.98
# 85   -5916.08
# 86   -5974.08
# 87   -6031.98
# 88   -6089.78
# 89   -6147.58
# 90   -6205.38
# 91   -6263.08
# 92   -6320.68
# 93   -6378.08
# 94   -6435.48
# 95   -6492.88
# 96   -6550.18
# 97   -6607.38
# 98   -6664.48
# 99   -6721.48
# ...

# %%
df1.head(100)
# Out:
#    world_rank  teaching international  research  citations income total_score  \
# 0           1      99.7          72.4      98.7       98.8   34.5        96.1
# 1           2      97.7          54.6      98.0       99.9   83.7        96.0
# 2           3      97.8          82.3      91.4       99.9   87.5        95.6
# 3           4      98.3          29.5      98.1       99.2   64.3        94.3
# 4           5      90.9          70.3      95.4       99.9      -        94.2
# 5           6      90.5          77.7      94.1       94.0   57.0        91.2
# 6           6      88.2          77.2      93.9       95.1   73.5        91.2
# 7           8      84.2          39.6      99.3       97.8      -        91.1
# 8           9      89.2          90.0      94.5       88.3   92.9        90.6
# 9          10      92.1          59.2      89.7       91.5      -        89.5
# 10         11      83.0          48.1      92.9       93.2      -        87.7
# ...

# %%
df1 = df.replace(np.nan, '-', regex=True)
df_test = df1[df1["total_score"]=='-']
df1 =  df1[df1["total_score"]!='-']
df1['female'] = df1['female_male_ratio'].str.split(':', expand=True)[0].apply(convertToInt)
df1['male'] = df1['female_male_ratio'].str.split(':', expand=True)[1].apply(convertToInt)
df1['num_students'] = df1['num_students'].apply(lambda x: str(x).replace(',','')).apply(convertToInt)
df1['international_students'] = df1['international_students'].apply(lambda x: str(x).replace('%','')).apply(convertToInt)
df1 = df1.drop(['female_male_ratio'], axis=1)
df1 = df1.drop(['year'], axis=1)
df1=df1.drop(['university_name'], axis=1)
df1=df1.drop(['country'], axis=1)
